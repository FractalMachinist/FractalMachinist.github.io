# %%
import requests, json

# %%
with open("personal_track/indeed_cookies.json", 'r') as cookies_json: indeed_cookies = json.load(cookies_json)

# %%
r = requests.get("https://myjobs.indeed.com/api/v1/appStatusJobs?type=POST_APPLY", cookies=indeed_cookies)

# %%
r.status_code
# Out:
# 200

# %%
r.json()["body"]["appStatusJobs"]
# Out:
# [{'appTk': '1ghtvvskkii1i803',
#   'jobTitle': 'Lead Full Stack Developer',
#   'jobKey': '380b46762c2b36b7',
#   'jobUrl': 'https://www.indeed.com/viewjob?jk=380b46762c2b36b7&hl=en',
#   'jobExpired': False,
#   'jobReported': False,
#   'jobFraudulent': False,
#   'withdrawn': False,
#   'location': 'Remote',
#   'company': {'name': 'Tinybeans',
#    'logoUrl': 'https://d2q79iu7y748jz.cloudfront.net/s/_squarelogo/9c58fd714d33e8c73abd877fbf51a874'},
#   'statuses': {'candidateStatus': None,
#    'selfReportedStatus': {'status': 'APPLIED', 'timestamp': 1668462167573},
#    'employerJobStatus': None,
#    'userJobStatus': {'status': 'POST_APPLY', 'timestamp': 1668462167573}},
#   'applyTime': 1668462167573,
#   'indeedApplyable': True,
#   'hasIaAppId': False,
#   'hasApplicationPreview': False,
#   'applicantsCountRange': {'lowerEndApplicantsCountRange': 31,
#    'upperEndApplicantsCountRange': 35},
#   'normalizedJobTitle': 'full stack developer',
#   'messaging': None,
# ...
