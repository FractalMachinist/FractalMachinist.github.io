# %%
import pandas as pd, skill_cat
from jobs_skills_weights import get_jobs_skills_weights

# %%
jsw = get_jobs_skills_weights(enforce_bookmarked=False)

# %%
agg_union_sets = lambda series: set().union(*series.tolist())

# %%
all_cats = skill_cat.category_to_skills.keys()
all_skills = skill_cat.skill_to_categories.keys()

# %%
jsw.loc["Ansys", :, "c"]
# Out:
#                                                          post  \
#                                                    excitement
# (post, id)                           (skill, name)
# bd59469c-29f4-41b9-9001-5b7902d766e1 c                      4
#
#                                                                    skill  \
#                                                                 category
# (post, id)                           (skill, name)
# bd59469c-29f4-41b9-9001-5b7902d766e1 c              functional abilities
#
#                                                               resume
#                                                       share category
# (post, id)                           (skill, name)
# bd59469c-29f4-41b9-9001-5b7902d766e1 c              0.01087   {Code}

# %%
jsw.droplevel(3).groupby(level=[0, 1, 2]).agg(share=(("skill", "share"), "sum")).loc["AFRY"].sort_values("share", ascending=False)
# Out:
#                                                              share
# (post, id)                           (skill, name_stem)
# 47b391b9-5f8e-4449-9e6f-f6156692edcb experience           0.133333
#                                      global               0.044444
#                                      creating             0.044444
#                                      requirements         0.044444
#                                      transition           0.044444
#                                      communication        0.044444
#                                      collaboration        0.044444
#                                      infrastructure       0.022222
#                                      tensorflow           0.022222
#                                      strong               0.022222
#                                      search engines       0.022222
#                                      anomaly detection    0.022222
#                                      recruitment          0.022222
#                                      python               0.022222
#                                      partner              0.022222
#                                      ownership            0.022222
#                                      machine learning     0.022222
#                                      java                 0.022222
#                                      integration          0.022222
#                                      innovative           0.022222
#                                      implementation       0.022222
#                                      curious              0.022222
#                                      implement solutions  0.022222
#                                      actively             0.022222
#                                      frameworks           0.022222
#                                      feature engineering  0.022222
#                                      extensive            0.022222
#                                      experts              0.022222
#                                      excellent            0.022222
#                                      deep learning        0.022222
#                                      deep                 0.022222
#                                      data science         0.022222
#                                      data                 0.022222
#                                      ability              0.022222

# %%
jsw.groupby(level=[0, 1]).agg({("resume", "category"):agg_union_sets})
# Out:
#                                                                                                                                     resume
#                                                                                                                                   category
# (post, name)                                       (post, id)
# AFRY                                               47b391b9-5f8e-4449-9e6f-f6156692edcb  {Soft, Admin, Code, ML, Project, Java, Data, W...
# Accenture                                          2fd852e6-d4cd-4e48-8e83-826e52a6a12b                   {Admin, Project, Code, Data, ML}
# Ada Health                                         077a5779-7d63-468e-b61f-29b0b9828e95  {Soft, Admin, Code, Writing, ML, Bio, Project,...
# Advanced Micro Devices                             f9454138-5a6a-4682-ad21-fb67d7572ab6  {Soft, Code, Admin, Writing, ML, Project, Data...
# Ansys                                              bd59469c-29f4-41b9-9001-5b7902d766e1  {Soft, Admin, Code, ML, Project, Data, Academi...
# Applied Materials                                  47b871fd-7d5a-401e-925e-c0023b37b8a0  {Soft, Admin, Code, ML, Project, Java, Data, A...
# Aptiv                                              8e40408b-ce12-4bfa-8927-776538e5ae97    {Admin, Soft, Project, Code, Data, ML, Writing}
# Arm                                                8ff399d2-0c05-42ed-a62e-5f06e794d513  {Soft, Admin, Code, Writing, ML, Project, Acad...
# Azumio                                             6a824f0c-1e42-4f12-ab84-398f3bf4c381   {Admin, Soft, Project, Code, Data, ML, Academic}
# BAE Systems Digital Intelligence                   47563f47-8c09-4536-a4c0-927870aa60e4       {Soft, Admin, Code, ML, Project, Java, Data}
# Bentley Systems                                    6e355b6d-2ad9-49e1-b731-c47cc5f51d9f  {Soft, Admin, Code, ML, Project, Data, Academi...
# CARIAD                                             bade64bd-50ec-4bfa-9a7b-a05b6ac5b040             {Admin, Soft, Project, Code, Data, ML}
# Carrier                                            af52fb94-ee33-48f4-8417-58d76aca2cfe  {Soft, Admin, Code, ML, Project, Data, Academi...
# Change Healthcare Technologies, Llc                b1d5551a-27a4-49ce-baf1-ee19d119e664  {Soft, Admin, Code, Writing, ML, Bio, Project,...
# Charles River Analytics                            75dfc8a2-74fc-46fb-b442-0bc6fae444cf  {Soft, Admin, Code, ML, Project, Data, Academi...
# Charles River Analytics Inc                        c83bb4c6-8c73-4023-9fbd-a410ab00b80b   {Soft, Admin, Code, ML, Project, Data, Academic}
# Coactive AI                                        59a9b3cc-5ee1-4533-80c4-beee53ff90b0  {Soft, Admin, Code, ML, Project, Java, Data, A...
# Continental                                        2459aa1c-8d46-4cb4-ade9-3c60b426197a  {Soft, Admin, Code, ML, Project, Data, Academi...
#                                                    446a5d05-dc36-4049-9cf3-fc4f9251555c  {Soft, Admin, Code, Writing, ML, Project, Data...
# Deepcell                                           8c3d7c4a-4e09-4d78-8871-1619a19b4b1d    {Soft, Admin, Code, ML, Project, Data, Writing}
# Embark Veterinary                                  7689e376-0626-48bd-8000-63e64c00fcda  {Bio, Project, Admin, Data, Visual, ML, Academ...
# Etsy                                               be097da1-22f9-4576-b112-47d8750bb8eb  {Soft, Code, Admin, Writing, ML, Project, Java...
# FARO Technologies                                  3d489a47-a20b-46c8-b500-0d41f5fed1ad  {Soft, Admin, Code, ML, Project, Data, Academi...
# FATHOM                                             ea715a81-16c4-44d9-9896-2982079fefbe         {Admin, Project, Code, Data, ML, Academic}
# GSK                                                fdd15faa-0804-4b07-9f55-715436213e75  {Soft, Admin, Code, ML, Bio, Project, Data, Ac...
# Grammarly                                          b0b1c693-46e4-4cd7-a4f9-3cb476c594b9  {Soft, Admin, Code, Writing, ML, Project, Data...
# Helsing                                            35b60a7d-f9a3-4f63-b8ab-4db8db49fca8  {Soft, Admin, Code, ML, Project, Java, Data, A...
# IBM                                                1681148f-1e70-4f27-8e51-31539f2eb0c4  {Soft, Admin, Code, ML, Bio, Project, Java, Da...
# Inari                                              d67b29de-1fc6-42a6-8290-a9c14db31404   {Soft, Project, Admin, Data, ML, Academic, Code}
# Invenia Labs                                       180d9af6-8691-4081-a68e-05dea56b2877  {Admin, Soft, Project, Code, Data, Writing, ML...
# LEIDOS                                             bc025b35-d830-4ba0-98f1-95d5c1e04d4e  {Admin, Code, ML, Project, Data, Academic, Wri...
# Lightmatter                                        ee6ac56f-c8cd-4000-bf43-477ff5464c5f              {Admin, Bio, Project, Code, Academic}
# Meltwater                                          11f7268b-eb7e-47d5-9e6a-48f3eb310b50  {Soft, Admin, Code, ML, Project, Java, Data, A...
# Mind Foundry                                       3b1391fe-c8bc-49c7-9832-6045b3751c57  {Soft, Admin, Code, Visual, ML, Project, Java,...
# Mosaic ML                                          e3fc2e48-8d44-4407-8d56-ec094284b2a7  {Soft, Admin, Code, Writing, ML, Visual, Proje...
# Motional                                           12e30a7c-316b-4538-9f8a-5942e1f898f3  {Soft, Code, Admin, Writing, ML, Project, Java...
# NXP Semiconductors                                 0a44990f-934d-4894-bdee-b8a65ea674ad   {Soft, Admin, Code, ML, Project, Data, Academic}
# Netherlands eScience Center                        43db2061-ef7d-4cad-831f-38096413df69   {Soft, Admin, Code, ML, Project, Data, Academic}
# Nokia                                              3f9325d5-ce50-48cf-adad-1d958afeb550  {Soft, Admin, Code, Writing, ML, Project, Data...
# Ozone                                              6e7c13f1-9c5f-4f5a-96f0-06d270220313   {Soft, Admin, Code, ML, Project, Data, Academic}
# Qualcomm                                           30ec026e-cc3f-448c-a70b-7f99827b4507  {Soft, Admin, Code, ML, Project, Java, Data, W...
# Reverie Labs                                       36bfb565-ecc5-4265-9822-f993b6f0ca25         {Admin, Project, Code, Data, ML, Academic}
# TIB – Leibniz-Informationszentrum Technik und N... 840fe7b5-0545-4737-a8e9-64cc64960a3d  {Soft, Admin, Code, Writing, ML, Project, Java...
# The Mathworks                                      ad72b01e-2459-49e6-b4d4-9bd9b8312b2d  {Admin, Soft, Project, Code, Data, Visual, ML,...
# Thumbtack                                          82d868d4-e7d3-475e-918d-cb1ed36757b3        {Soft, Bio, Project, Admin, Data, ML, Code}
# Tobii                                              756db9a6-f350-4563-9738-4ce5c89f222b       {Project, Code, Data, Writing, ML, Academic}
# Treibacher Industrie AG                            0124e218-2d33-41e8-907b-5228ea386455  {Soft, Code, Admin, Writing, ML, Project, Java...
# Unit21                                             3a1faef4-844f-4615-be0b-323999f5495a    {Soft, Admin, Code, ML, Project, Data, Writing}
# Verhaert Masters in Innovation                     3e26baad-a862-43d9-aad6-71bb38a45b67  {Soft, Code, Admin, Writing, ML, Project, Data...
# Viasat Inc                                         1beec747-ee6e-48fa-94cf-01b4e5be0a8b  {Soft, Admin, Code, ML, Project, Java, Data, A...
# Weights and Biases                                 3da2e1f7-6d0c-43a8-93d4-d1e72e820b4a         {Admin, Soft, Project, Code, ML, Academic}
# insitro                                            159cbd59-1453-4f90-aa8d-0a8703b62c6d  {Soft, Admin, Code, ML, Bio, Project, Java, Da...
